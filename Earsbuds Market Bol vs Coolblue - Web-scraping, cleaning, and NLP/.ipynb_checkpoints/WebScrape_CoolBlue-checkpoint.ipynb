# %% [markdown]
# # Web-scraping of Coolblue.nl
#
# This notebooks contains a scapring tool of Coolblue.nl using Python's beautiful soup. The goal of this program is to export a dataframe which can be used to compare Bol.com with CoolBlue in my other program.
#
# Let's what the website looks like.

# %%
from IPython.display import Image
Image(filename='CoolBlue.png')

# %%
import os
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd
import re
from math import nan

## REQUIRED FUNCTIONS
def join_string(word_list):
    string=''
    for word in word_list:
        string=string+' '+word
    return string[1:]

def price_list_to_price(price_list):
    if len(price_list)==1:
        return price_list[0]
    else:
        return price_list[0]+price_list[1]/100

def get_digits(str1):
    c = ""
    for i in str1:
        if i.isdigit():
            c += i
    return c

# %%
url = 'https://www.coolblue.nl/oordopjes/draadloos?pagina=1'

page_read = BeautifulSoup(requests.get(url).text, 'html.parser')
products = page_read.find_all('div', {'class': 'product-card grid-container grid-container-xs--gap-4--x grid-container-xs--gap-2--y grid-container-l--gap-4--y js-product grid-container-l--gap-1--x'})

product=products[0]
len(products)
# Out:
# 22

# %% [markdown]
# We have 22 products per page so that's correct. The soup is split in 22 products.

# %%
Prod_name=join_string(product.h3.text.split()[1:])
Man_name=product.h3.text.split()[0]

print(Man_name)
print(Prod_name)
# Out:
# Apple
# AirPods Pro met Draadloze Oplaadcase

# %% [markdown]
# This is not the same as on the picture since the website changes.
#
# Now, let's scrape the price and discount rates.

# %%
## PRICING
try:
    Price_string=product.find('span','sales-price sales-price--small js-sales-price').strong.text
    Price_list=[int(s) for s in Price_string.split(',') if s.isdigit()] #Convert to ints
    Price=price_list_to_price(Price_list) #Concat int list to a price

    Retail_Price=Price
# Sometimes an 'advies' prijs and current price is given, lets get them    
except:  
    Retail_Price_string=product.find('span','sales-price__former-price').text
    Retail_Price_list=Retail_Price_string.split(',')
    Retail_Price_list_ints=[]
    for Retail_Price_str_el in Retail_Price_list:
        element=get_digits(Retail_Price_str_el)
        if len(element)>0:
            Retail_Price_list_ints.append(int(element))
    Retail_Price=price_list_to_price(Retail_Price_list_ints)


    Price_string=product.find('strong','sales-price__current').text
    Price_list=[int(s) for s in Price_string.split(',') if s.isdigit()] #Convert to ints
    Price=price_list_to_price(Price_list) #Concat int list to a price    print(Prod_name) 

# Determine discount rates
Discount=-int((Price-Retail_Price)/Retail_Price*100)
Discount=str(Discount)+'%'
    
print('Current price, ',Price,' EUR')
print('Retail price,  ',Retail_Price,' EUR')
print('Discount rate, ',Discount)
# Out:
# Current price,  156.99  EUR
# Retail price,   156.99  EUR
# Discount rate,  0%

# %% [markdown]
# In this case the discount rate is determined from the current and retail price. This results in a 0% discount for this product.
#
# Now, let's see how this product is rated overall on CoolBlue:

# %%
Review=product.find('div',{'class':'review-rating__icons'}).get('title').split()
Stars=float(Review[0])
Star_count=int(Review[-2])
print('Stars, ', Stars)
print('# Reviewers, ', Star_count)
# Out:
# Stars,  4.5
# # Reviewers,  193

# %% [markdown]
# Quite some reviewers, with a total score of 4.5. Now let's discover what kind of product it is based on the description:

# %%
## DESCRIPTION
product_url=product.find('div',{'class':'product-card__title'}).a.get('href')
product_page_read = BeautifulSoup(requests.get('https://www.coolblue.nl' +product_url).text, 'html5lib')

try:
    descr=product_page_read.find('div',{'class':'js-product-description'}).p.text.split()
    descr=' '.join(descr)
except:
    descr='No description'
    
descr
# Out:
# 'Met de Jabra Elite 75t heb je geen last van kabels tijdens het luisteren naar muziek. Deze volledig draadloze oordopjes zijn 20% kleiner dan zijn voorganger, de 65t. Hierdoor zitten ze comfortabeler en vallen ze minder snel uit je oren. De batterij van de oordopjes gaat 7,5 uur mee, dit is langer dan bij andere volledig draadloze oordopjes. Doordat de oordopjes waterbestendig zijn, sport je er ook mee. Je laadt de oordopjes op door ze in de oplaad case te stoppen. Deze case geeft een extra batterijduur van 20,5 uur. Er worden standaard verschillende maten oordopjes meegeleverd. Probeer deze uit, zodat je eenvoudig de juiste pasvorm vindt.'

# %% [markdown]
# I decided to preprocess the text a little already. This makes it easier to verify the code for myself.

# %%
 ## PROS AND CONS
points=product_page_read.find_all('div',{'class':'js-pros-and-cons'})[0]
labels=points.find_all('span',{'class':'screen-reader-only'})
points_list=points.find_all('div') # Sometimes a plus sometimes a minus, check this with a loop
plus_list=[]
minus_list=[]
for i in range(0,len(labels)):
    label=labels[i].text
    if label == 'Pluspunt:':
        plus=points_list[2+3*i].text.split()
        plus_list.append(' '.join(plus))
    elif label == 'Minpunt:':
        minus=points_list[2+3*i].text.split()
        minus_list.append(' '.join(minus))
        
print('Pros: ',plus_list)
print('Cons: ',minus_list)
# Out:
# Pros:  ['De Jabra Elite 75t is 20% kleiner dan zijn voorganger, de 65t.', 'Op een volle lading gaan de oordopjes 7,5 uur mee, dat is langer dan bij andere volledig draadloze oordopjes.', 'De oordopjes zijn waterbestendig, waardoor je er ook mee sport.']
# Cons:  ['Er worden geen schuimoordoppen meegeleverd.']

# %% [markdown]
# This was all the general feedback of the product. Now, let's dive deeper and actually get some independent reviews by the customers. Note that this is sometimes quite tricky. However, below verifies the code.

# %%
## REVIEWS       
reviews=product_page_read.select('p[class*="grid-section-xs--gap-3"]')
review_stars=product_page_read.find_all('span',{'class':'review-rating__reviews overflow--ellipsis'})

got_expert_review=product_page_read.text.find('Onze specialistenreview') # Sometimes the first review is an expert review which should be removed
if got_expert_review>0:
    reviews=reviews[1:]

# %% [markdown]
# We also want to assign a rating to each review. Let's start getting the ratings. These were not easy to scrape:

# %%
# Load star ratings in list and split this list to only include reviews given in the subwindow
star_list=[]
for review_star in review_stars:
    if len(get_digits(review_star.text))==2:
        star_for_review=int(get_digits(review_star.text))
        if star_for_review==10:
            star_list.append(star_for_review)
        else:
            star_list.append(star_for_review/10)

# Remove rest of star_ratings
for k in range(int(len(star_list)/2),len(star_list)):
    star_list[k]='Double review'  # Rather do it this way for code robustness
star_list
# Out:
# [5.4,
#  1.6,
#  8.4,
#  8.0,
#  9.6,
#  9.2,
#  10,
#  8.8,
#  10,
#  10,
#  'Double review',
#  'Double review',
#  'Double review',
#  'Double review',
#  'Double review',
#  'Double review',
#  'Double review',
#  'Double review',
#  'Double review',
#  'Double review']

# %% [markdown]
# Now we would like to combine the reviews with these ratings. I have flipped the star_list to make it more convenient.

# %%
# Put them together in a review list
star_list=np.flip(star_list)    
review_list=[]
for i in range(0,int(len(reviews)/2)):
      review=reviews[i].text.split()
      review_list.append(' '.join(review)+', '+ str(star_list[len(star_list)-1-i]))#
      if str(star_list[len(star_list)-1-i])=='Double review':
          review_list=review_list[:-1]
review_list
# Out:
# ['Het draagcomfort is fantastisch. Bijna direct nadat je ze in je oren hebt laten glijden vergeet je dat je ze in hebt. Direct na aanschaf was ik bang dat ze er zo uit zouden vallen, maar dat gebeurt niet. Ook bij 5 minuten touwtje springen, 100 burpees of een uur rammen op Zwift. Waar ik echt veel meer van had verwacht is de kwaliteit van het bellen. "ZIT JE IN DE KELDER" is een veelgehoorde vraag als ik met iemand aan het bellen ben. En ja, natuurlijk heb ik de laatste firmware geïnstalleerd. En omdat ik voor mijn werk veel moet bellen vind ik deze oordoppen ongeschikt voor beltijgers die zakelijke gesprekken moeten voeren., 5.4',
#  'Vooral gekocht om mee te sporten (hardlopen en ergometer), maar loop er inmiddels halve dagen mee rond. Zitten goed, mooi geluid dat desgewenst met equalizer bij te stellen is, chique compact design, batterijen willen maar niet leeg. Heel blij mee! Zijn er nadelen? Ja: bij de hear through functie levert fietsen behoorlijk wat windgeruis op, en tijdens het hardlopen hoor je een zachte bonk bij het neerzetten van je voet. Dat laatste wende overigens heel snel., 1.6',
#  'Zie pluspunten. Juist op deze pluspunten uitgezocht, dus prima naar mijn wensen, 8.4',
#  'Was initieel wat teleurgesteld, de bas was veel te heftig en bonkerig, bas ruim in de min gezet (als echte bass lover)en na 3 dagen klonk deze veel ronder en vol, hoog/midden iets aangezet...voila,,,een prachtig geluid uit zulke kleine dopjes...af en toe (kort!)wegvallertje..tja dat doen ze allemaal., 8.0',
#  'Geweldig geluid, zit perfect., 9.6',
#  'Heb ze nog niet lang maar werken heel goed en zitten ook comfortabel, 9.2',
#  'Top earbuds. Geweldige voor hardstyle muziek met dikke bass., 10',
#  'Hele goeie oortjes voor dagelijks gebruik. Goeie prijs kwaliteit verhouden, oortjes/case hebben een mooi en klein design, de muziek kwaliteit is heel goed (en met de app kan je het helemaal aanpassen aan jouw smaak), de oortjes gaan heel lang mee, ze blijven goed zitten, het gebruikersgemak is geweldig (je kan via een knopje op beide oortjes volume aanpassen, muziek aan of uit zetten, siri of google assistent inschakelen, hearthrough in/uitzetten en terug/doorspoelen), de app is ook heel makkelijk te gebruiken. Op de oortjes zit geen noice-canceling, maar dat is ook niet nodig. Ze sluiten goed aan waardoor het handig is dat er hear-through op zit waardoor je wel je omgeving kan horen. Ook kan je met deze oortjes in de regen lopen/fietsen etc. zonder problemen. Het is ook echt een update op de Jabra 65t. Kortom: echt een aanrader! Zeker het geld waard!, 8.8',
#  "Super fijne oordopjes met lange accuduur. Mooie case erbij met usb c aansluiting. De app is ook een fijn, hier kun je op verschillende maken je geluid regelen en zie je de stand van de accu van de oordopjes en case op je telefoon. Persoonlijk vind ik het geluid nog beter icm de dolby atmos functie op m'n Samsung telefoon. Toen ik die inschakelde was ik volledig overtuigd van de keuze. Het verbinden via Bluetooth ging helemaal perfect! Geen enkele moeite. De knoppen op de oordopjes zijn ook super fijn, via de app kun je ook instellen of je hear through in wilt schakelen op je oordop knop of niet. De oordopjes zitten stevig in je oren mits je ze goed in je oren draait. Zitten ze goed dan kun je er alles mee doen zonder angst dat ze er uitvallen. Ik ben erg blij met deze aankoop en geniet van mooi geluid met lange accuduur en zonder irritante draadjes. ALs ik negatief punt zou moeten noemen is dat het comfort van de rubberen dopjes, naeen tijdje deed deze pijn aan m'n oren. Ik had echter eerst een te grote maat van rubberen dopjes, daarna naar de kleinste maat overgestapt, maar toen waren m'n oren al wat pijnlijk., 10"]

# %% [markdown]
# All the above should be looped over all products and all pages. This will be done below.
#
# This program was unit tested while building in Spyder. For visualisation purposes it was transferred to Jupyter Notebook afterwards. Please refer to WEB_SCAPE_COOLBLUE.py for the original script.

# %%
## INITIALISE VARIABLES
CoolBlue_data=[]
url = 'https://www.coolblue.nl/oordopjes/draadloos?pagina='
endpage=9
pages=np.arange(1,endpage+1)
pages=[1]
for Npage in pages: # Loop over pages
    print('Page=',Npage)
    ## READ PAGES
    page_read = BeautifulSoup(requests.get(url+str(Npage)).text, 'html.parser')
    products = page_read.find_all('div', {'class': 'product-card grid-container grid-container-xs--gap-4--x grid-container-xs--gap-2--y grid-container-l--gap-4--y js-product grid-container-l--gap-1--x'})
    products=products[0:4]
    for product in products: # Loop over products per page
        ## MANUFACTURER AND PRODUCT NAME
        Prod_name=join_string(product.h3.text.split()[1:])
        Man_name=product.h3.text.split()[0]
        print(Prod_name)
        ## PRICING
        try:
            Price_string=product.find('span','sales-price sales-price--small js-sales-price').strong.text
            Price_list=[int(s) for s in Price_string.split(',') if s.isdigit()] #Convert to ints
            Price=price_list_to_price(Price_list) #Concat int list to a price
            
            Retail_Price=Price
        # Sometimes an 'advies' prijs and current price is given, lets get them    
        except:  
            Retail_Price_string=product.find('span','sales-price__former-price').text
            Retail_Price_list=Retail_Price_string.split(',')
            Retail_Price_list_ints=[]
            for Retail_Price_str_el in Retail_Price_list:
                element=get_digits(Retail_Price_str_el)
                if len(element)>0:
                    Retail_Price_list_ints.append(int(element))
            Retail_Price=price_list_to_price(Retail_Price_list_ints)
    
            
            Price_string=product.find('strong','sales-price__current').text
            Price_list=[int(s) for s in Price_string.split(',') if s.isdigit()] #Convert to ints
            Price=price_list_to_price(Price_list) #Concat int list to a price    print(Prod_name) 
        
        # Determine discount rates
        Discount=-int((Price-Retail_Price)/Retail_Price*100)
        Discount=str(Discount)+'%'
    
       ## STAR RATING
        Review=product.find('div',{'class':'review-rating__icons'}).get('title').split()
        Stars=float(Review[0])
        Star_count=int(Review[-2])
        if Star_count==0:
            Stars='No review'
            
        ## DESCRIPTION
        product_url=product.find('div',{'class':'product-card__title'}).a.get('href')
        product_page_read = BeautifulSoup(requests.get('https://www.coolblue.nl' +product_url).text, 'html5lib')
        
        try:
            descr=product_page_read.find('div',{'class':'js-product-description'}).p.text.split()
            descr=' '.join(descr)
        except:
            descr='No description'
        
         ## PROS 
        points=product_page_read.find_all('div',{'class':'js-pros-and-cons'})[0]
        labels=points.find_all('span',{'class':'screen-reader-only'})
        points_list=points.find_all('div')
        plus_list=[]
        minus_list=[]
        for i in range(0,len(labels)):
            label=labels[i].text
            if label == 'Pluspunt:':
                plus=points_list[2+3*i].text.split()
                plus_list.append(' '.join(plus))
            elif label == 'Minpunt:':
                minus=points_list[2+3*i].text.split()
                minus_list.append(' '.join(minus))
        
        ## REVIEWS       
        reviews=product_page_read.select('p[class*="grid-section-xs--gap-3"]')
        review_stars=product_page_read.find_all('span',{'class':'review-rating__reviews overflow--ellipsis'})
        
        got_expert_review=product_page_read.text.find('Onze specialistenreview') # Sometimes the first review is an expert review which should be removed
        if got_expert_review>0:
            reviews=reviews[1:]
        
        # Load star ratings in list and split this list to only include reviews given in the subwindow
        star_list=[]
        for review_star in review_stars:
            if len(get_digits(review_star.text))==2:
                star_for_review=int(get_digits(review_star.text))
                if star_for_review==10:
                    star_list.append(star_for_review)
                else:
                    star_list.append(star_for_review/10)
        
        # Remove rest of star_ratings
        for k in range(int(len(star_list)/2),len(star_list)):
            star_list[k]='Double review'  # Rather do it this way for code robustness
        
        # Put them together in a review list
        star_list=np.flip(star_list)    
        review_list=[]
        for i in range(0,int(len(reviews)/2)):
              review=reviews[i].text.split()
              review_list.append(' '.join(review)+', '+ str(star_list[len(star_list)-1-i]))#
              if str(star_list[len(star_list)-1-i])=='Double review':
                  review_list=review_list[:-1]
                  
        CoolBlue_data.append([Man_name,Prod_name,Price,Discount,round(Retail_Price,2),Stars,Star_count,descr,plus_list,minus_list,review_list])


# Create DF
col_names=['Manufacturer','Name','Price [EUR]','Discount','Ret P [EUR]','Stars [x/5.0]', 'S_count','Description','Pros','Cons','Reviews']
EarBuds_CoolBlue = pd.DataFrame(np.array(CoolBlue_data),columns=col_names)
EarBuds_CoolBlue['Price [EUR]']=EarBuds_CoolBlue['Price [EUR]'].apply(lambda x: float(x))
EarBuds_CoolBlue['Ret P [EUR]']=EarBuds_CoolBlue['Ret P [EUR]'].apply(lambda x: float(x))
EarBuds_CoolBlue['S_count']=EarBuds_CoolBlue['S_count'].apply(lambda x: int(x))

#EarBuds_CoolBlue.to_pickle('EarBuds_CoolBlue')
# Out:
# Page= 1
# AirPods Pro met Draadloze Oplaadcase
# AirPods 2 met oplaadcase
# Powerbeats Pro Zwart
# Elite 75t Titanium Zwart

# %%
EarBuds_CoolBlue.head()
# Out:
#   Manufacturer                                  Name  Price [EUR] Discount  \
# 0        Apple  AirPods Pro met Draadloze Oplaadcase       259.00       0%
# 1        Apple              AirPods 2 met oplaadcase       149.00       0%
# 2        Beats                  Powerbeats Pro Zwart       225.00       0%
# 3        Jabra              Elite 75t Titanium Zwart       156.99       0%
#
#    Ret P [EUR] Stars [x/5.0]  S_count  \
# 0       259.00           4.5      662
# 1       149.00           4.5     3181
# 2       225.00           4.5      252
# 3       156.99           4.5      193
#
#                                          Description  \
# 0  Met Apple AirPods Pro worden jouw favoriete de...
# 1  Let op: de meegeleverde oplaadcase laad je all...
# 2  Haal het beste in jezelf naar boven tijdens he...
# 3  Met de Jabra Elite 75t heb je geen last van ka...
#
#                                                 Pros  \
# 0  [Actieve noise cancelling dempt storende omgev...
# 1  [Dankzij de H1 chip verbind je de oordopjes au...
# 2  [Door het volledig draadloze ontwerp heb je ge...
# 3  [De Jabra Elite 75t is 20% kleiner dan zijn vo...
#
#                                                 Cons  \
# 0  [Je hebt een Apple iPhone, iPad of Mac nodig o...
# 1  [Je hebt een Apple iPhone, iPad of Mac nodig o...
# 2  [De draagwijze is minder geschikt voor brildra...
# 3      [Er worden geen schuimoordoppen meegeleverd.]
#
#                                              Reviews
# 0  [Eindelijk fatsoenlijke noice cancelling in oo...
# 1  [Ik heb deze AirPods generatie 2 gekocht omdat...
# 2  [Al sinds de aankondiging was ik aan het wacht...
# 3  [Het draagcomfort is fantastisch. Bijna direct...

# %%
EarBuds_CoolBlue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Manufacturer   4 non-null      object
#  1   Name           4 non-null      object
#  2   Price [EUR]    4 non-null      float64
#  3   Discount       4 non-null      object
#  4   Ret P [EUR]    4 non-null      float64
#  5   Stars [x/5.0]  4 non-null      object
#  6   S_count        4 non-null      int64
#  7   Description    4 non-null      object
#  8   Pros           4 non-null      object
#  9   Cons           4 non-null      object
#  10  Reviews        4 non-null      object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 480.0+ bytes

# %%
EarBuds_CoolBlue.describe()
# Out:
#        Price [EUR]  Ret P [EUR]      S_count
# count     4.000000     4.000000     4.000000
# mean    197.497500   197.497500  1072.000000
# std      53.328573    53.328573  1421.386881
# min     149.000000   149.000000   193.000000
# 25%     154.992500   154.992500   237.250000
# 50%     190.995000   190.995000   457.000000
# 75%     233.500000   233.500000  1291.750000
# max     259.000000   259.000000  3181.000000

# %% [markdown]
# All looks very good. Note that this will change when ran at different times as CoolBlue is a fast changing E-comm.
